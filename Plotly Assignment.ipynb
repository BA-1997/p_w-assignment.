# %% [markdown]
# # Q1. Load the "titanic" dataset using the load_dataset function of seaborn. Use Plotly express to plot a scatter plot for age and fare columns in the titanic dataset.

# %%
import plotly.express as px
import seaborn as sns

# %%
td = sns.load_dataset("titanic")

# %%
td.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
fig = px.scatter(td,x="age",y="fare")
fig.update_layout(title = "Scatter Plot og Age vs Fare in titanic Dataset")
fig.show()

# %% [markdown]
# # Q2. Using the tips dataset in the Plotly library, plot a box plot using Plotly express.

# %%
tips_data = px.data.tips()

# %%
tips_data.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
fig = px.box(tips_data,x="day", y="total_bill",color="sex",notched=True)
fig.update_layout(title="Box Plot of Total Bill by Day and Sex",
                  xaxis_title="Day",
                  yaxis_title="Total Bill")
fig.show()

# %% [markdown]
# # Q3. Using the tips dataset in the Plotly library, Plot a histogram for x= "sex" and y="total_bill" column in the tips dataset. Also, use the "smoker" column with the pattern_shape parameter and the "day" column with the color parameter.

# %%
fig = px.histogram(tips_data, x= "sex" ,y="total_bill",pattern_shape="smoker",color="day")
fig.update_layout(title="Histogram of Sex by Total Bill",
                  xaxis_title="Sex",
                  yaxis_title="Total Bill")
fig.show()

# %% [markdown]
# # Q4. Using the iris dataset in the Plotly library, Plot a scatter matrix plot, using the "species" column for the color parameter.
# Note: Use "sepal_length", "sepal_width", "petal_length", "petal_width" columns only with the dimensions parameter.

# %%
id = px.data.iris()
id.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species  species_id
# 0           5.1          3.5           1.4          0.2  setosa           1
# 1           4.9          3.0           1.4          0.2  setosa           1
# 2           4.7          3.2           1.3          0.2  setosa           1

# %%
fig = px.scatter_matrix(id,dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],color="species")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30120\732915106.py in ?()
# ----> 1 fig = px.scatter_matrix(id,dimensions=["sepal_length", "sepal_width", "petal_length", "petal_width"],color="species")
#       2 fig.show()
#
# ~\anaconda3\Lib\site-packages\plotly\express\_chart_types.py in ?(data_frame, dimensions, color, symbol, size, hover_name, hover_data, custom_data, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, symbol_sequence, symbol_map, opacity, size_max, title, template, width, height)
#    1388     represented by a multiple symbol marks, one in each cell of a grid of
#    1389     2D scatter plots, which plot each pair of `dimensions` against each
#    1390     other.
#    1391     """
# -> 1392     return make_figure(
# ...

# %% [markdown]
# # Q5. What is Distplot? Using Plotly express, plot a distplot.

# %% [markdown]
# A Distplot or distribution plot, depicts the variation in the data distribution
#
# In Plotly Express, the distplot function is used to create a distribution plot, which is also known as a histogram with a kernel density estimate (KDE) overlaid on top. A distribution plot provides a visual representation of the distribution of a single numerical variable.

# %%
fig = px.histogram(tips_data, x="total_bill", y="tip", color="sex",
                   marginal="box", # or violin, rug
                   hover_data=tips_data.columns)

fig.show()
